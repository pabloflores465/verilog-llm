# %% [markdown]
# # Verilog SOTA Training — Qwen2.5-Coder-14B
#
# **Tokens required in Kaggle Secrets** (right panel → Add Secret):
# - `HF_TOKEN` = `YOUR_HF_TOKEN_HERE`
# - `KAGGLE_KEY` = `YOUR_KAGGLE_KEY_HERE`
#
# **Dataset input**: `pablofloresmollinedo/verilog-curated-dataset`
# **Hub output**: `pabloflores/verilog-qwen-14b-sota`
#
# Run all cells. Training auto-resumes from last checkpoint.

# %%
# !pip install -q -U bitsandbytes>=0.46.1
# !pip install -q transformers peft trl datasets accelerate huggingface-hub
# !pip install -q sentencepiece protobuf

# %%
# Full training script is in the project repo:
# https://github.com/pabloflores465/verilog-llm
#
# Download and run the script:
# !wget -q https://raw.githubusercontent.com/pabloflores465/verilog-llm/main/scripts/kaggle_script.py
# %run kaggle_script.py
